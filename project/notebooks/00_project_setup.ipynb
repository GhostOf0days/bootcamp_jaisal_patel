# %% [markdown]
# # Environment & Config Check
#
# Stage 02. **I based it on the lecture notebook.**

# %%
# Install missing packages (uncomment and run to install).
# !pip install numpy python-dotenv

# %%
from pathlib import Path

# Project root.
ROOT = Path.cwd()
if not (ROOT / ".env.example").exists() and (ROOT.parent / ".env.example").exists():
    ROOT = ROOT.parent

CHECKS = [
    (".env", "NEEDED", "copy .env.example to .env"),
    (".env.example", "NEEDED", "template for local secrets"),
]

print(f"Looking in: {ROOT}\n")
missing = 0
for rel, kind, note in CHECKS:
    here = (ROOT / rel).exists()
    if not here and kind == "NEEDED":
        missing += 1
    print(f"  [{'OK ' if here else 'MISS'}]  {kind:<8}  {rel:<34}  {note}")

if missing:
    raise FileNotFoundError(f"{missing} needed file(s) missing under {ROOT}")
print("\nAll needed files present.")
# Out:
# Looking in: /Users/ghostof0days/projects/bootcamp/project
#
#   [OK ]  NEEDED    .env                                copy .env.example to .env
#   [OK ]  NEEDED    .env.example                        template for local secrets
#
# All needed files present.

# %% [markdown]
# ## Verify interpreter

# %%
import sys
print("Python version:", sys.version)
print("Interpreter path:", sys.executable)
# Out:
# Python version: 3.10.20 (main, Jun 11 2026, 15:14:28) [Clang 20.1.8 ]
# Interpreter path: /opt/anaconda3/envs/bootcamp_env/bin/python

# %% [markdown]
# ## Imports

# %%
import numpy as np
import sys

# Import helpers from src/config.py.
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from src.config import load_env, get_key, PROJECT_ROOT, DATA_DIR
print("Imports OK")
# Out:
# Imports OK

# %% [markdown]
# ## Load `.env`

# %%
# Load `.env`.
load_env()
print(".env loaded (if present)")
# Out:
# .env loaded (if present)

# %% [markdown]
# ## Config paths

# %%
print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATA_DIR:", DATA_DIR)
# Out:
# PROJECT_ROOT: /Users/ghostof0days/projects/bootcamp/project/notebooks
# DATA_DIR: /Users/ghostof0days/projects/bootcamp/project/notebooks/data

# %% [markdown]
# ## Check API_KEY and DATA_DIR

# %%
api_key_present = get_key("API_KEY") is not None
data_dir_env = get_key("DATA_DIR", str(DATA_DIR)) or str(DATA_DIR)
print("API_KEY present:", api_key_present)
print("DATA_DIR from env:", data_dir_env)

# Create the data folder.
Path(data_dir_env).mkdir(parents=True, exist_ok=True)
print("Ensured data directory exists.")
# Out:
# API_KEY present: True
# DATA_DIR from env: ./data
# Ensured data directory exists.

# %% [markdown]
# ## NumPy mini-demo

# %%
# Small NumPy array.
arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Mean:", arr.mean())
print("Vectorized * 10:", arr * 10)
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Vectorized * 10: [10 20 30 40 50]
